# %%
import pandas as pd

df = pd.read_csv('TSLA.csv', parse_dates=["Date"])
df = df[df["Date"].dt.strftime("%Y") == "2018"]

format_dict = {
    "Date": "{:%d/%m/%y}",
    "Open": "${:.2f}",
    "High": "${:.2f}",
    "Low": "${:.2f}",
    "Close": "${:.2f}",
    "Ajd Close": "${:.2f}",
    "Volume": "{:,}",
}

# %%
(
    df.style.format(format_dict)
    .highlight_min(["Open"], color="red")
    .highlight_max(["Open"], color="green")
    .background_gradient(subset="Close", cmap="Greens")
    .bar('Volume', color='lightblue', align='zero')
    .set_caption('Tesla Stock Prices in 2018')
    .hide()
)
# Out:
# <style type="text/css">
# #T_7313b_row0_col4, #T_7313b_row137_col4 {
#   background-color: #63bc6e;
#   color: #f1f1f1;
# }
# #T_7313b_row0_col5, #T_7313b_row79_col5, #T_7313b_row80_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 56.5%, transparent 56.5%);
# }
# #T_7313b_row1_col4 {
#   background-color: #6dc072;
#   color: #000000;
# }
# #T_7313b_row1_col5, #T_7313b_row17_col5, #T_7313b_row184_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 56.7%, transparent 56.7%);
# }
# #T_7313b_row2_col4, #T_7313b_row206_col4 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_7313b_row2_col5, #T_7313b_row249_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 64.8%, transparent 64.8%);
# }
# #T_7313b_row3_col4, #T_7313b_row132_col4 {
#   background-color: #6ec173;
#   color: #000000;
# }
# #T_7313b_row3_col5, #T_7313b_row29_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 56.8%, transparent 56.8%);
# }
# #T_7313b_row4_col4 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_7313b_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 64.7%, transparent 64.7%);
# }
# #T_7313b_row5_col4, #T_7313b_row34_col4, #T_7313b_row42_col4, #T_7313b_row119_col4 {
#   background-color: #3da65a;
#   color: #f1f1f1;
# }
# #T_7313b_row5_col5, #T_7313b_row10_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 60.6%, transparent 60.6%);
# }
# #T_7313b_row6_col4, #T_7313b_row33_col4, #T_7313b_row41_col4, #T_7313b_row125_col4, #T_7313b_row208_col4 {
#   background-color: #3aa357;
#   color: #f1f1f1;
# }
# #T_7313b_row6_col5, #T_7313b_row37_col5, #T_7313b_row43_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 56.4%, transparent 56.4%);
# }
# #T_7313b_row7_col4, #T_7313b_row225_col4 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_7313b_row7_col5, #T_7313b_row56_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 59.9%, transparent 59.9%);
# }
# #T_7313b_row8_col4 {
#   background-color: #38a156;
#   color: #f1f1f1;
# }
# #T_7313b_row8_col5, #T_7313b_row183_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 57.2%, transparent 57.2%);
# }
# #T_7313b_row9_col4 {
#   background-color: #309950;
#   color: #f1f1f1;
# }
# #T_7313b_row9_col5, #T_7313b_row124_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 59.6%, transparent 59.6%);
# }
# #T_7313b_row10_col4 {
#   background-color: #238b45;
#   color: #f1f1f1;
# }
# #T_7313b_row11_col4, #T_7313b_row112_col4, #T_7313b_row122_col4 {
#   background-color: #289049;
#   color: #f1f1f1;
# }
# #T_7313b_row11_col5, #T_7313b_row32_col5, #T_7313b_row75_col5, #T_7313b_row77_col5, #T_7313b_row89_col5, #T_7313b_row93_col5, #T_7313b_row101_col5, #T_7313b_row136_col5, #T_7313b_row231_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 58.4%, transparent 58.4%);
# }
# #T_7313b_row12_col4, #T_7313b_row123_col4 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_7313b_row12_col5, #T_7313b_row55_col5, #T_7313b_row76_col5, #T_7313b_row131_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 57.3%, transparent 57.3%);
# }
# #T_7313b_row13_col4, #T_7313b_row216_col4 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_7313b_row13_col5, #T_7313b_row20_col5, #T_7313b_row198_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 59.2%, transparent 59.2%);
# }
# #T_7313b_row14_col4, #T_7313b_row116_col4, #T_7313b_row152_col4 {
#   background-color: #17813d;
#   color: #f1f1f1;
# }
# #T_7313b_row14_col5, #T_7313b_row104_col5, #T_7313b_row201_col5, #T_7313b_row219_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 58.1%, transparent 58.1%);
# }
# #T_7313b_row15_col4, #T_7313b_row19_col4, #T_7313b_row35_col4, #T_7313b_row227_col4 {
#   background-color: #258d47;
#   color: #f1f1f1;
# }
# #T_7313b_row15_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 57.9%, transparent 57.9%);
# }
# #T_7313b_row16_col4, #T_7313b_row210_col4 {
#   background-color: #359e53;
#   color: #f1f1f1;
# }
# #T_7313b_row16_col5, #T_7313b_row214_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 60.0%, transparent 60.0%);
# }
# #T_7313b_row17_col4, #T_7313b_row39_col4, #T_7313b_row124_col4 {
#   background-color: #2b934b;
#   color: #f1f1f1;
# }
# #T_7313b_row18_col4, #T_7313b_row147_col4 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_7313b_row18_col5, #T_7313b_row38_col5, #T_7313b_row53_col5, #T_7313b_row105_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 57.1%, transparent 57.1%);
# }
# #T_7313b_row19_col5, #T_7313b_row90_col5, #T_7313b_row225_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 57.0%, transparent 57.0%);
# }
# #T_7313b_row20_col4, #T_7313b_row222_col4 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_7313b_row21_col4 {
#   background-color: #1f8742;
#   color: #f1f1f1;
# }
# #T_7313b_row21_col5, #T_7313b_row99_col5, #T_7313b_row226_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 56.2%, transparent 56.2%);
# }
# #T_7313b_row22_col4 {
#   background-color: #2a924a;
#   color: #f1f1f1;
# }
# #T_7313b_row22_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 55.5%, transparent 55.5%);
# }
# #T_7313b_row23_col4, #T_7313b_row120_col4, #T_7313b_row243_col4, #T_7313b_row250_col4 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_7313b_row23_col5, #T_7313b_row94_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 56.6%, transparent 56.6%);
# }
# #T_7313b_row24_col4, #T_7313b_row31_col4, #T_7313b_row249_col4 {
#   background-color: #3ca559;
#   color: #f1f1f1;
# }
# #T_7313b_row24_col5, #T_7313b_row41_col5, #T_7313b_row162_col5, #T_7313b_row217_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 57.6%, transparent 57.6%);
# }
# #T_7313b_row25_col4 {
#   background-color: #278f48;
#   color: #f1f1f1;
# }
# #T_7313b_row25_col5, #T_7313b_row35_col5, #T_7313b_row72_col5, #T_7313b_row135_col5, #T_7313b_row155_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 60.4%, transparent 60.4%);
# }
# #T_7313b_row26_col4, #T_7313b_row244_col4 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_7313b_row26_col5, #T_7313b_row119_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 65.3%, transparent 65.3%);
# }
# #T_7313b_row27_col4, #T_7313b_row134_col4 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_7313b_row27_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 69.2%, transparent 69.2%);
# }
# #T_7313b_row28_col4 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_7313b_row28_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 59.3%, transparent 59.3%);
# }
# #T_7313b_row29_col4, #T_7313b_row136_col4 {
#   background-color: #58b668;
#   color: #f1f1f1;
# }
# #T_7313b_row30_col4, #T_7313b_row130_col4 {
#   background-color: #5db96b;
#   color: #f1f1f1;
# }
# #T_7313b_row30_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 55.9%, transparent 55.9%);
# }
# #T_7313b_row31_col5, #T_7313b_row87_col5, #T_7313b_row103_col5, #T_7313b_row137_col5, #T_7313b_row161_col5 {
#   width: 10em;
#   background:
